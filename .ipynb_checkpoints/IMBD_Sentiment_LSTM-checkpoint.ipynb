# %%
import time 
import math
import re
import json

from bs4 import BeautifulSoup

import spacy

import numpy as np
import pandas as pd

import gensim.models
from gensim.models import KeyedVectors



from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.metrics import classification_report

import torch
import torch.nn as nn

import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# %%
IMDB_Dataset = pd.read_csv("IMDB Dataset.csv")

# %%
IMDB_Dataset['review'][0].split()[:10]
# Out:
# ['One',
#  'of',
#  'the',
#  'other',
#  'reviewers',
#  'has',
#  'mentioned',
#  'that',
#  'after',
#  'watching']

# %%
nlp = spacy.load('en_core_web_sm')
stopwords = nlp.Defaults.stop_words

# %%
# extracting text from tags 
def strip_html(text):
    soup = BeautifulSoup(text, "html.parser")
    return soup.get_text()

# removing square brackets
def remove_between_square_brackets(text):
    return re.sub('\[[^]]*\]', '', text)

# lemmatization and removal of stop words
def lemma(text):
    doc = nlp(text.lower())
    lemmas = [token.lemma_ for token in doc 
          if (token.lemma_.isalnum() or token.lemma_ in ['.', '!', '?'] ) and token.lemma_ not in stopwords]
    text = ' '.join(lemmas)
    return text

# cleaning text
def clean(text):
    text = strip_html(text)
    text = remove_between_square_brackets(text)
    text = lemma(text)
    return text

# %%
# IMDB_Dataset_Clean = IMDB_Dataset.copy()
# IMDB_Dataset_Clean['review'] = IMDB_Dataset['review'].apply(clean)
# IMDB_Dataset_Clean.to_csv('IMDB_Dataset_Clean.csv')

# %%
IMDB_Dataset_Clean = pd.read_csv('IMDB_Dataset_Clean.csv')

# %%
sentences = []
_ = [sentences.append(x.split()) for x in IMDB_Dataset_Clean['review']]

# %%
t = time.time()

word2vec_model = gensim.models.Word2Vec(
    sentences=sentences,
    window=10,
    min_count=1,
    negative=5,
    vector_size=100, 
    workers=12)

word2vec_model.save('./saved_models/word2vec_model')

print('Time to build vocab: {} mins'.format(round((time.time() - t) / 60, 2)))
# Out:
# Time to build vocab: 0.13 mins

# %%
word2vecDict = {}
for index, word in enumerate(word2vec_model.wv.index_to_key):
    word2vecDict[word] = word2vec_model.wv.vectors[index]

# %%
list(word2vecDict.keys())[:10]
# Out:
# ['.', 'I', 'movie', 'film', '!', 'like', 'good', 'time', '?', 'character']

# %%
movie_reviews_vectorized = []
for review in IMDB_Dataset_Clean['review']:
    temp = []
    for word in review.split():
        temp.append(word2vecDict[word])
    movie_reviews_vectorized.append(np.array(temp))

# %%
# first 3 words of first movie review
print(IMDB_Dataset_Clean['review'][0].split()[:3])
print('\n')
print(movie_reviews_vectorized[0][:3])
# Out:
# ['reviewer', 'mention', 'watch']
#
#
# [[-4.82579648e-01 -1.04284346e+00 -2.29939842e+00 -3.45665038e-01
#    1.40963149e+00 -2.12393332e+00  2.06206584e+00  1.33040261e+00
#   -2.05921507e+00 -1.71413386e+00  2.04878354e+00 -3.60651314e-02
#   -1.95166469e+00 -6.94890469e-02  8.71251881e-01 -1.79483439e-03
#    1.23447835e+00  1.32793105e+00  4.67268705e-01 -2.43221730e-01
#    6.38812423e-01  2.28217915e-02  2.97454262e+00 -1.85316586e+00
#    2.94923753e-01 -1.26753819e+00 -1.26133561e-02  6.43177032e-02
#    9.19908941e-01  2.94657379e-01  1.62598264e+00 -2.81860903e-02
#    1.25029111e+00 -4.18807983e-01  1.08704233e+00  9.06443536e-01
#    1.84437132e+00  9.08355713e-01 -1.98652792e+00  3.86353046e-01
#   -5.06173134e-01 -1.83600211e+00 -1.56626487e+00  9.66974080e-01
#   -7.56106377e-01  2.50418162e+00 -2.02199054e+00  1.98397923e+00
#   -5.39802015e-01 -4.28741127e-02 -3.59456182e-01  1.35450959e-01
#   -1.02361774e+00 -5.15249491e-01 -8.55426073e-01  2.54651427e+00
#    3.07263017e+00  1.05842066e+00  2.11783171e-01  1.12131572e+00
#    8.43629003e-01  8.20030570e-01  8.06421757e-01 -1.69587588e+00
#    6.15983009e-01  9.33063269e-01 -1.68860018e+00  8.77832174e-02
#   -1.24295342e+00  1.14431739e+00  5.32852672e-02 -1.00605845e+00
#    5.35907865e-01  1.93318105e+00  7.41707146e-01 -7.94570804e-01
#   -1.04516876e+00  4.60140519e-02 -6.57479465e-01 -2.38780394e-01
#    1.28801477e+00  1.16833150e+00  1.15246928e+00 -1.18965614e+00
#    8.68350208e-01 -1.27879053e-01  2.78142601e-01 -1.20691669e+00
#    3.85001779e-01 -7.94037879e-01  1.07623652e-01  1.95841861e+00
#    1.94809902e+00 -9.50818837e-01 -1.58849645e+00  1.53475404e-01
#    6.93822503e-01  1.82931674e+00 -4.87130582e-01 -1.20068207e-01]
#  [ 4.27980781e-01 -2.43932769e-01 -2.29012632e+00 -1.41673291e+00
#    1.76343930e+00  2.34755754e+00  1.54208088e+00  1.21317476e-01
#   -4.72259410e-02  7.65657067e-01  1.45528901e+00  2.33797625e-01
#   -1.92346609e+00  3.39888990e-01  1.58991110e+00  2.24140072e+00
#   -1.07600594e+00  1.19175601e+00 -1.63076389e+00  4.92035508e-01
#   -3.05246592e-01 -1.11109710e+00  2.09939107e-01  8.24841082e-01
#   -1.80933273e+00 -1.19454101e-01  1.87847823e-01  8.83897960e-01
#    1.31904638e+00 -1.39229798e+00  1.88908115e-01 -3.49440485e-01
#    7.45129228e-01 -6.59744382e-01 -1.55817246e+00 -1.31142473e+00
#    1.31232572e+00 -6.26301706e-01 -1.70935869e+00  1.45950332e-01
#   -2.31374979e+00 -2.08582473e+00 -9.87220049e-01 -5.54535151e-01
#    4.42732185e-01  5.43982267e-01 -6.15456343e-01  1.76936492e-01
#   -6.83437213e-02  2.29100680e+00 -5.86073518e-01  3.68832946e-01
#   -6.45456165e-02 -8.13828826e-01  1.55062690e-01  1.14268863e+00
#    9.27985668e-01  5.70633531e-01  1.16301608e+00 -7.47794330e-01
#    2.13592386e+00 -4.31912601e-01  1.13190830e+00 -6.58452690e-01
#   -2.27844238e-01  1.13058829e+00  4.87453103e-01 -7.12663174e-01
#   -8.67299199e-01  1.61360323e-01 -1.87025630e+00  1.25599194e+00
#   -6.16755188e-01  9.19462979e-01 -2.41895556e-01  2.31909439e-01
#    7.14073479e-01  1.62821925e+00 -1.40500569e+00 -7.39813864e-01
#   -2.41759084e-02  5.74237965e-02  1.90046763e+00  1.06232274e+00
#    1.68417346e+00  1.74431697e-01  9.98477697e-01  4.34096605e-01
#    3.94832641e-01 -1.27379072e+00 -4.63611990e-01  2.31323576e+00
#    1.10281467e+00 -1.54237199e+00  6.01746619e-01  7.99698770e-01
#   -2.76590794e-01  6.60547793e-01  2.41344237e+00  5.16190886e-01]
#  [ 6.45688891e-01 -2.92617202e+00 -4.91111726e-01 -7.28321373e-01
#   -2.14564180e+00  3.10642660e-01  1.20721960e+00 -4.50738859e+00
#   -1.10765016e+00 -1.29502511e+00  3.98527771e-01  3.04002261e+00
#    2.55554342e+00 -2.42637920e+00 -1.76390803e+00  3.94361839e-02
#    1.92471266e+00  1.57327807e+00  2.12780547e+00 -1.17220604e+00
#   -1.77308714e+00 -1.16371036e+00  3.67688328e-01 -6.15576267e-01
#   -2.03663492e+00 -9.71224532e-02 -3.81192374e+00 -2.16717318e-01
#    3.96285713e-01  1.29377913e+00 -7.12762475e-01 -9.92893040e-01
#   -5.33494204e-02 -3.40483260e+00  1.26835835e+00  1.47296643e+00
#    1.87657714e+00  2.64753532e+00 -2.28444314e+00 -2.33909369e+00
#   -1.01286590e+00 -1.65844703e+00 -2.88765311e+00  4.05873597e-01
#    5.96982002e-01  6.80920064e-01 -3.73410869e+00 -9.67389286e-01
#   -2.60978699e-01  6.20508552e-01  1.01019265e-02  4.61857170e-01
#    2.46402789e-02 -9.06951129e-01 -2.28774905e+00  1.38472170e-01
#    5.28159618e-01 -6.64809719e-02  5.36958694e-01  2.12283090e-01
#   -1.55208349e+00 -3.29570341e+00  1.69751084e+00 -1.06417084e+00
#   -6.86954409e-02  2.16455460e+00  1.14948630e+00  9.03735399e-01
#   -1.63851488e+00 -3.67625058e-02 -8.69325340e-01  3.43831801e+00
#   -2.50639260e-01  2.19008255e+00  2.09797120e+00  3.12328148e+00
#    1.79692757e+00 -1.71028304e+00  6.85275495e-01 -1.89284217e+00
#    1.17338145e+00  4.15996701e-01  3.31278300e+00  7.07716882e-01
#   -1.87861764e+00 -9.22665745e-02  7.97417939e-01  1.44073471e-01
#    5.33238947e-01 -1.19363630e+00  2.74721694e+00  1.04804039e+00
#    8.86613965e-01  1.10855162e-01 -2.87972903e+00 -3.36247623e-01
#    3.85291219e-01 -1.54187262e+00  2.27562413e-01 -6.20228648e-01]]

# %%
# encoding sentiment
le = preprocessing.LabelEncoder()
movie_reviews_sentiment = le.fit_transform(IMDB_Dataset_Clean['sentiment'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [12], line 2
#       1 # encoding sentiment
# ----> 2 le = preprocessing.LabelEncoder()
#       3 movie_reviews_sentiment = le.fit_transform(IMDB_Dataset_Clean['sentiment'])
#
# NameError: name 'preprocessing' is not defined

# %%
# train, validation, test: 80/10/10 
X_train, X_test, y_train, y_test = train_test_split(movie_reviews_vectorized, movie_reviews_sentiment, test_size=1/4, random_state=1)
X_validation, X_test, y_validation, y_test = train_test_split(X_test, y_test, test_size=1/2, random_state=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [13], line 2
#       1 # train, validation, test: 80/10/10
# ----> 2 X_train, X_test, y_train, y_test = train_test_split(movie_reviews_vectorized, movie_reviews_sentiment, test_size=1/4, random_state=1)
#       3 X_validation, X_test, y_validation, y_test = train_test_split(X_test, y_test, test_size=1/2, random_state=1)
#
# NameError: name 'train_test_split' is not defined

# %%
class LSTM(nn.Module):
    def __init__(self, input_size, hidden_size, output_size, num_layers, dropout, bidirectional):
        super(LSTM, self).__init__()
        
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        
        if bidirectional: self.bidirectional = 2
        else: self.bidirectional = 1
        
        if num_layers < 2:
            dropout = 0
        
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers=num_layers, dropout=dropout, bidirectional=bidirectional)
        self.dropout = nn.Dropout(0.2)
        self.fc = nn.Linear(hidden_size*self.bidirectional, output_size)
        self.softmax = nn.LogSoftmax(dim=1)
    
    def forward(self, input, hidden, c):
        output, (hidden, c) = self.lstm(input, (hidden, c))
        output = self.dropout(output)
        output = output.squeeze()[-1].unsqueeze(0)
        output = self.fc(output)
        output = self.softmax(output)
        return output, hidden, c
    
    def initHidden(self):
        return torch.zeros(self.bidirectional*self.num_layers, 1, self.hidden_size)
    def initC(self):
        return torch.zeros(self.bidirectional*self.num_layers, 1, self.hidden_size)

# %%
def getLabel(output):
    value_tensor, index_tensor = output.topk(1)
    return index_tensor[0].item()

# %%
def getElapsedTime(start_time):
    current_time = time.time()
    s = current_time - start_time
    m = math.floor(s / 60)
    s -= m * 60
    return '{}m {:.0f}s'.format(m, s)

# %%
def train(X_train, y_train):
    hidden, c = lstm.initHidden(), lstm.initC()
    lstm.zero_grad()
    output, hidden, c = lstm(X_train, hidden, c)
    loss = criterion(output, y_train)
    loss.backward()
    nn.utils.clip_grad_norm_(lstm.parameters(), 5)
    optimizer.step()

    return output, loss.item()

# %%
def test(X_test, y_test):
    n = len(X_test)
    print_every = 1000
    
    correct = 0
    total_loss = 0
    
    y_pred = []
    
    for i in range(n):
        with torch.no_grad():
            hidden, c = lstm.initHidden(), lstm.initC()
            output, hidden, c = lstm(torch.tensor(X_test[i]).unsqueeze(1), hidden, c)
            loss = criterion(output, torch.tensor([y_test[i]], dtype=torch.long))
            total_loss+=loss.item()
            
            y_pred.append(getLabel(output))
            if y_pred[-1] == y_test[i]:
                correct+=1
            
            if i>0 and i%print_every == 0:
                pass
#                 print('Test Sample {} | {:.2f}%'.format(i, i*100/n))
                
                
    accuracy = correct / n
    total_loss = total_loss / n
    
    return accuracy, total_loss

# %%
# strict parameters
input_size = len(X_train[0][0])
output_size = 2

# adjustable parameters
hidden_size = 128
num_layers = 1
dropout = .1
bidirectional = True


lstm = LSTM(input_size, hidden_size, output_size, num_layers, dropout, bidirectional)
criterion = nn.NLLLoss()
lr = 0.001
optimizer = torch.optim.SGD(lstm.parameters(), lr=lr)

# %%
epochs = 10

n = len(X_train)

print_every = 5000
plot_every = 1000

start_time = time.time()

total_epoch_loss = []
total_validation_loss = []

total_validation_accuracy = []

for epoch in range(epochs):
    epoch_loss = []
    current_loss = 0
    
    lstm.train()
        
    for i in range(n):
        
        output, loss = train(torch.tensor(X_train[i]).unsqueeze(1), torch.tensor([y_train[i]], dtype=torch.long))
        current_loss += loss
    
        if i>0 and i % print_every == 0:
            y_pred = getLabel(output)
            if y_pred == y_train[i]:
                y_pred = "Correct! It's {}".format(y_pred)  
            else:
                y_pred = 'Wrong! Guessed {} but should be: {}'.format(y_pred, y_train[i])
        
            print('Epoch %d Sample %d | %d%% | (%s) | Loss: %.4f | %s' % (epoch, i, i / n * 100, getElapsedTime(start_time), loss, y_pred))

        if i>0 and i % plot_every == 0:
            epoch_loss.append(current_loss / plot_every)
            current_loss = 0
            
    print('\n')
            
    # training loss
    training_loss = sum(epoch_loss) / len(epoch_loss)
    
    # validation loss
    lstm.eval()
    validation_accuracy, validation_loss = test(X_validation, y_validation)
    
    # save metrics if continuing
    total_epoch_loss.append(training_loss)
    total_validation_accuracy.append(validation_accuracy)
    total_validation_loss.append(validation_loss)
    
    # save model
    torch.save(lstm.state_dict(), './saved_models/lstm_epoch_{}.pth'.format(epoch))
    
    # plot current epoch loss
    plt.title('Epoch {} Loss'.format(epoch))
    plt.plot(epoch_loss)
    plt.ylabel('Loss')
    plt.show()
# Out:
# Epoch 0 Sample 5000 | 13% | (3m 5s) | Loss: 0.4902 | Correct! It's 1
# Epoch 0 Sample 10000 | 26% | (6m 1s) | Loss: 0.2836 | Correct! It's 0
# Epoch 0 Sample 15000 | 40% | (8m 58s) | Loss: 0.4051 | Correct! It's 1
# Epoch 0 Sample 20000 | 53% | (11m 53s) | Loss: 0.1279 | Correct! It's 0
# Epoch 0 Sample 25000 | 66% | (14m 45s) | Loss: 0.1827 | Correct! It's 0
# Epoch 0 Sample 30000 | 80% | (17m 40s) | Loss: 1.2438 | Wrong! Guessed 1 but should be: 0
# Epoch 0 Sample 35000 | 93% | (20m 35s) | Loss: 0.0369 | Correct! It's 0
# Epoch 1 Sample 5000 | 13% | (25m 37s) | Loss: 0.0209 | Correct! It's 1
# Epoch 1 Sample 10000 | 26% | (28m 32s) | Loss: 1.5624 | Wrong! Guessed 1 but should be: 0
# Epoch 1 Sample 15000 | 40% | (31m 30s) | Loss: 0.0503 | Correct! It's 1
# Epoch 1 Sample 20000 | 53% | (34m 26s) | Loss: 0.0332 | Correct! It's 0
# Epoch 1 Sample 25000 | 66% | (37m 18s) | Loss: 0.0591 | Correct! It's 0
# Epoch 1 Sample 30000 | 80% | (40m 13s) | Loss: 2.4975 | Wrong! Guessed 1 but should be: 0
# Epoch 1 Sample 35000 | 93% | (43m 8s) | Loss: 0.0154 | Correct! It's 0
# Epoch 2 Sample 5000 | 13% | (48m 9s) | Loss: 0.0238 | Correct! It's 1
# Epoch 2 Sample 10000 | 26% | (51m 4s) | Loss: 1.9264 | Wrong! Guessed 1 but should be: 0
# Epoch 2 Sample 15000 | 40% | (54m 2s) | Loss: 0.0410 | Correct! It's 1
# Epoch 2 Sample 20000 | 53% | (56m 58s) | Loss: 0.0323 | Correct! It's 0
# Epoch 2 Sample 25000 | 66% | (59m 51s) | Loss: 0.0423 | Correct! It's 0
# Epoch 2 Sample 30000 | 80% | (62m 46s) | Loss: 1.2536 | Wrong! Guessed 1 but should be: 0
# Epoch 2 Sample 35000 | 93% | (65m 43s) | Loss: 0.0217 | Correct! It's 0
# Epoch 3 Sample 5000 | 13% | (70m 45s) | Loss: 0.0162 | Correct! It's 1
# Epoch 3 Sample 10000 | 26% | (73m 41s) | Loss: 1.7331 | Wrong! Guessed 1 but should be: 0
# Epoch 3 Sample 15000 | 40% | (76m 38s) | Loss: 0.0313 | Correct! It's 1
# Epoch 3 Sample 20000 | 53% | (79m 34s) | Loss: 0.0116 | Correct! It's 0
# Epoch 3 Sample 25000 | 66% | (82m 26s) | Loss: 0.0123 | Correct! It's 0
# Epoch 3 Sample 30000 | 80% | (85m 21s) | Loss: 0.1381 | Correct! It's 0
# Epoch 3 Sample 35000 | 93% | (88m 17s) | Loss: 0.0107 | Correct! It's 0
# Epoch 4 Sample 5000 | 13% | (93m 18s) | Loss: 0.0312 | Correct! It's 1
# Epoch 4 Sample 10000 | 26% | (96m 14s) | Loss: 1.9705 | Wrong! Guessed 1 but should be: 0
# Epoch 4 Sample 15000 | 40% | (99m 12s) | Loss: 0.0240 | Correct! It's 1
# Epoch 4 Sample 20000 | 53% | (102m 8s) | Loss: 0.0130 | Correct! It's 0
# Epoch 4 Sample 25000 | 66% | (105m 0s) | Loss: 0.0140 | Correct! It's 0
# Epoch 4 Sample 30000 | 80% | (107m 55s) | Loss: 1.7288 | Wrong! Guessed 1 but should be: 0
# Epoch 4 Sample 35000 | 93% | (110m 50s) | Loss: 0.0151 | Correct! It's 0
# Epoch 5 Sample 5000 | 13% | (115m 52s) | Loss: 0.0200 | Correct! It's 1
# Epoch 5 Sample 10000 | 26% | (118m 48s) | Loss: 1.8510 | Wrong! Guessed 1 but should be: 0
# Epoch 5 Sample 15000 | 40% | (121m 46s) | Loss: 0.0122 | Correct! It's 1
# Epoch 5 Sample 20000 | 53% | (124m 41s) | Loss: 0.0226 | Correct! It's 0
# Epoch 5 Sample 25000 | 66% | (127m 33s) | Loss: 0.0127 | Correct! It's 0
# Epoch 5 Sample 30000 | 80% | (130m 29s) | Loss: 1.4612 | Wrong! Guessed 1 but should be: 0
# Epoch 5 Sample 35000 | 93% | (133m 24s) | Loss: 0.0210 | Correct! It's 0
# Epoch 6 Sample 5000 | 13% | (138m 27s) | Loss: 0.0193 | Correct! It's 1
# Epoch 6 Sample 10000 | 26% | (141m 23s) | Loss: 1.8641 | Wrong! Guessed 1 but should be: 0
# Epoch 6 Sample 15000 | 40% | (144m 20s) | Loss: 0.0232 | Correct! It's 1
# Epoch 6 Sample 20000 | 53% | (147m 15s) | Loss: 0.0101 | Correct! It's 0
# Epoch 6 Sample 25000 | 66% | (150m 7s) | Loss: 0.0104 | Correct! It's 0
# Epoch 6 Sample 30000 | 80% | (153m 2s) | Loss: 1.5069 | Wrong! Guessed 1 but should be: 0
# Epoch 6 Sample 35000 | 93% | (155m 58s) | Loss: 0.0140 | Correct! It's 0
# Epoch 7 Sample 5000 | 13% | (160m 59s) | Loss: 0.0109 | Correct! It's 1
# Epoch 7 Sample 10000 | 26% | (163m 55s) | Loss: 1.6857 | Wrong! Guessed 1 but should be: 0
# Epoch 7 Sample 15000 | 40% | (166m 52s) | Loss: 0.0166 | Correct! It's 1
# Epoch 7 Sample 20000 | 53% | (169m 48s) | Loss: 0.0114 | Correct! It's 0
# Epoch 7 Sample 25000 | 66% | (172m 40s) | Loss: 0.0205 | Correct! It's 0
# Epoch 7 Sample 30000 | 80% | (175m 34s) | Loss: 1.3896 | Wrong! Guessed 1 but should be: 0
# Epoch 7 Sample 35000 | 93% | (178m 30s) | Loss: 0.0179 | Correct! It's 0
# Epoch 8 Sample 5000 | 13% | (183m 32s) | Loss: 0.0074 | Correct! It's 1
# Epoch 8 Sample 10000 | 26% | (186m 26s) | Loss: 2.2786 | Wrong! Guessed 1 but should be: 0
# Epoch 8 Sample 15000 | 40% | (189m 23s) | Loss: 0.0081 | Correct! It's 1
# Epoch 8 Sample 20000 | 53% | (192m 19s) | Loss: 0.0099 | Correct! It's 0
# Epoch 8 Sample 25000 | 66% | (195m 10s) | Loss: 0.0411 | Correct! It's 0
# Epoch 8 Sample 30000 | 80% | (198m 5s) | Loss: 1.0880 | Wrong! Guessed 1 but should be: 0
# Epoch 8 Sample 35000 | 93% | (201m 2s) | Loss: 0.0149 | Correct! It's 0
# Epoch 9 Sample 5000 | 13% | (206m 7s) | Loss: 0.0097 | Correct! It's 1
# Epoch 9 Sample 10000 | 26% | (209m 2s) | Loss: 2.1373 | Wrong! Guessed 1 but should be: 0
# Epoch 9 Sample 15000 | 40% | (211m 59s) | Loss: 0.0291 | Correct! It's 1
# Epoch 9 Sample 20000 | 53% | (214m 55s) | Loss: 0.0114 | Correct! It's 0
# Epoch 9 Sample 25000 | 66% | (217m 46s) | Loss: 0.0058 | Correct! It's 0
# Epoch 9 Sample 30000 | 80% | (220m 40s) | Loss: 1.2461 | Wrong! Guessed 1 but should be: 0
# Epoch 9 Sample 35000 | 93% | (223m 35s) | Loss: 0.0088 | Correct! It's 0

# %%
plt.title('Total Loss')
plt.plot(range(len(total_epoch_loss)), total_epoch_loss, label='Training Loss')
plt.plot(range(len(total_validation_loss)), total_validation_loss, label= 'Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

plt.title('Total Validation Accuracy')
plt.plot(total_validation_accuracy)
plt.show()

# %%
# final test
test_accuracy, test_loss = test(X_test, y_test)
print(test_accuracy)
# Out:
# 0.87344
